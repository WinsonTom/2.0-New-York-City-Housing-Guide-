# %%
import pandas as pd
import numpy as np
import os

# %%
#In an attempt to answer Question # 8, we had to carefully review each neighborhood & the population density 
#within them. However many of the neighborhoods were too general “South West Brooklyn”, “Central Harlem”, 
#“North-East Bronx”. I decided to dissect each of these generalized neighborhoods further 
#to get greater understanding of what each neighborhood’s population density is like. 
#As a result we will have to make edits to the columns: Population, Square Miles, Population Density, 
#Perceptions, and Neighborhood Safety Rating

# %%
#Load File Create DF
#Afterwards file is named B. Population_Density_New_Neighborhood.xlsx

DF = pd.read_excel('/Users/winsontom/Desktop/Career Foundry/Part 8- Final CF Immersion/2.0 Project/Population_Density5.xlsx', sheet_name='Sheet1')

# %%
#Here is the Population, Square Miles, and Population Density columns to fill out

DF
# Out:
#                                                 Address     Neighborhood  \
# 0                2 E 55th St Unit 803New York, NY 10022    Gramercy Park
# 1     Central Park Tower Penthouse-217 W 57th New Yo...          Chelsea
# 2               620 Sinclair AveStaten Island, NY 10312      South Shore
# 3            2 E 55th St Unit 908W33Manhattan, NY 10022    Gramercy Park
# 4                         5 E 64th StNew York, NY 10065  Upper East Side
# ...                                                 ...              ...
# 4549            222 E 80th St Apt 3AManhattan, NY 10075  Upper East Side
# 4550             97-40 62 Dr Unit LgRego Park, NY 11374        Rego Park
# 4551        427 W 21st St Unit GardenNew York, NY 10011          Chelsea
# 4552         91-23 Corona Ave Unit 4GElmhurst, NY 11373         Elmhurst
# 4553          460 Neptune Ave Apt 14OBrooklyn, NY 11224   Brighton Beach
#
#       Population  Square Miles  Population Density
# ...

# %%
#Data source for population: 
#https://data.cityofnewyork.us/City-Government/New-York-City-Population-By-Neighborhood-Tabulatio/swpk-hqdp/about_data

# %% [markdown]
# ## Input Population (Based on Neighborhood)

# %%
Neighborhoods:
Allerton
Astoria
Bath Beach
Battery Park City
Bay Chester
Bay Ridge
Baychester
Bayside
Bedford-Stuyvesant
Beechhurst
Bellerose
Belmont
Belmost
Bensonhurst
Boerum Hill
Borough Park
Brighton Beach
Brooklyn Heights
Brownsville
Cambria Heights
Canarsie
Carroll Gardens
Castle Hill
Chelsea
City Island
Clason Point
Clinton Hill
Co-op City
Cobble Hills
College Point
Coney Island
Corona
Country Club
Crotona Park East
Crown Heights
Douglaston
Dumbo
Dyker Heights
East Harlem
East New York
East Village
Edenwald
Elmhurst
Financial District
Flatbush
Floral Park
Flushing
Fordham
Fordham Heights
Forest Hills
Fort Greene
Fort Hamilton
Fresh Meadows
Gerritsen Beach
Glen Oaks
Glendale
Gowanus
Gramercy Park
Gravesend
Gravesend 
Green Point
Greenwich Village
Greenwood
Harding Park
Harlem
High Bridge
Homecrest
Howard Beach
Hunters Point
Hunts Point
Jackson Heights
Jamaica
Kew Gardens
Little Neck
Locust Point
Long Island City
Lower East Side
Malba
Manhattan Beach
Marine Park
Maspeth
Mid Island
Middle Village
Midwood
Morningside Heights
Morris Heights
Morris Park
New Hyde park
New Utretch
NoHo
Ocean Hill
Ozone Park
Park Slope
Parkchester
Pelham Bay
Pelham Gardens
Pelham Parkway
Port Richmond
Prospect Heights
Prospect Park
Queens Village
Red Hook
Rego Park
Richmond Hill
Ridgewood
Riverdale
Rockaway
Rosedale
Schuylerville
Seagate
Sheepshead Bay
Soho
Soundview
South Shore
South Street Seaport
Springfield
Springfield Gardens
Stapleton
Stuyvesant Heights
Sunnyside
Sunset Park
Throggs Neck
Tremont
Tribeca
Two Bridges
Upper East Side
Upper West Side
Van Nest
Vinegar Hill
Wakefield
Washington Heights
West Farms
Westchester Square
Whitestone
Williamsbridge
Williamsburg
Windsor Terrace
Woodhaven
Woodlawn
Woodside
# Out:
#   Cell In[7], line 1
#     Neighborhoods:
#                   ^
# SyntaxError: invalid syntax

# %%
DF.loc[DF['Neighborhood'] =='Allerton', 'Population'] = '28903'

# %%
DF.loc[DF['Neighborhood'] =='Astoria', 'Population'] = '106607'

# %%
DF.loc[DF['Neighborhood'] =='Bath Beach', 'Population'] = '29931'

# %%
DF.loc[DF['Neighborhood'] =='Battery Park City', 'Population'] = '39699'

# %%
DF.loc[DF['Neighborhood'] =='Bay Chester', 'Population'] = '5000'

# %%
DF.loc[DF['Neighborhood'] =='Bay Ridge', 'Population'] = '79371'

# %%
DF.loc[DF['Neighborhood'] =='Baychester', 'Population'] = '34517'

# %%
DF.loc[DF['Neighborhood'] =='Bayside', 'Population'] = '43808'

# %%
DF.loc[DF['Neighborhood'] =='Bedford-Stuyvesant', 'Population'] = '157530'

# %%
DF.loc[DF['Neighborhood'] =='Beechhurst', 'Population'] = '5171'

# %%
DF.loc[DF['Neighborhood'] =='Bellerose', 'Population'] = '25287'

# %%
DF.loc[DF['Neighborhood'] =='Belmont', 'Population'] = '27378'

# %%
##Remove, typo
DF.loc[DF['Neighborhood'] =='Belmost', 'Population'] = ''

# %%
DF.loc[DF['Neighborhood'] =='Bensonhurst', 'Population'] = '151705'

# %%
DF.loc[DF['Neighborhood'] =='Boerum Hill', 'Population'] = '34495'
# Out:
# /var/folders/yj/v30db1v90zs0p0pvttp796cm0000gp/T/ipykernel_1515/1032884998.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '34495' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   DF.loc[DF['Neighborhood'] =='Boerum Hill', 'Population'] = '34495'

# %%
DF.loc[DF['Neighborhood'] =='Borough Park', 'Population'] = '106357'

# %%
DF.loc[DF['Neighborhood'] =='Brighton Beach', 'Population'] = '35547'

# %%
DF.loc[DF['Neighborhood'] =='Brooklyn Heights', 'Population'] = '22887'

# %%
DF.loc[DF['Neighborhood'] =='Brownsville', 'Population'] = '58300'

# %%
DF.loc[DF['Neighborhood'] =='Cambria Heights', 'Population'] = '18677'

# %%
DF.loc[DF['Neighborhood'] =='Canarsie', 'Population'] = '83693'

# %%
DF.loc[DF['Neighborhood'] =='Carroll Gardens', 'Population'] = '38353'

# %%
DF.loc[DF['Neighborhood'] =='Castle Hill', 'Population'] = '53686'

# %%
DF.loc[DF['Neighborhood'] =='Chelsea', 'Population'] = '70150'

# %%
DF.loc[DF['Neighborhood'] =='City Island', 'Population'] = '26583'

# %%
DF.loc[DF['Neighborhood'] =='Clason Point', 'Population'] = '53686'

# %%
DF.loc[DF['Neighborhood'] =='Clinton Hill', 'Population'] = '34791'

# %%
DF.loc[DF['Neighborhood'] =='Co-op City', 'Population'] = '43752'

# %%
DF.loc[DF['Neighborhood'] =='Cobble Hills', 'Population'] = '22887'

# %%
DF.loc[DF['Neighborhood'] =='College Point', 'Population'] = '24275'

# %%
DF.loc[DF['Neighborhood'] =='Coney Island', 'Population'] = '31965'

# %%
DF.loc[DF['Neighborhood'] =='Corona', 'Population'] = '109695'

# %%
DF.loc[DF['Neighborhood'] =='Country Club', 'Population'] = '26583'

# %%
DF.loc[DF['Neighborhood'] =='Crotona Park East', 'Population'] = '20277'

# %%
DF.loc[DF['Neighborhood'] =='Crown Heights', 'Population'] = '142839'

# %%
DF.loc[DF['Neighborhood'] =='Douglaston', 'Population'] = '24739'

# %%
DF.loc[DF['Neighborhood'] =='Dumbo', 'Population'] = '34495'

# %%
DF.loc[DF['Neighborhood'] =='Dyker Heights', 'Population'] = '42419'

# %%
DF.loc[DF['Neighborhood'] =='East Harlem', 'Population'] = '115921'

# %%
DF.loc[DF['Neighborhood'] =='East New York', 'Population'] = '121301'

# %%
DF.loc[DF['Neighborhood'] =='East Village', 'Population'] = '44136'

# %%
DF.loc[DF['Neighborhood'] =='Edenwald', 'Population'] = '34517'

# %%
DF.loc[DF['Neighborhood'] =='Elmhurst', 'Population'] = '137098'

# %%
DF.loc[DF['Neighborhood'] =='Financial District', 'Population'] = '64511'

# %%
DF.loc[DF['Neighborhood'] =='Flatbush', 'Population'] = '156159'

# %%
DF.loc[DF['Neighborhood'] =='Floral Park', 'Population'] = '22571'

# %%
DF.loc[DF['Neighborhood'] =='Flushing', 'Population'] = '230183'

# %%
DF.loc[DF['Neighborhood'] =='Fordham', 'Population'] = '82677'

# %%
DF.loc[DF['Neighborhood'] =='Fordham Heights', 'Population'] = '27875'

# %%
DF.loc[DF['Neighborhood'] =='Forest Hills', 'Population'] = '83728'

# %%
DF.loc[DF['Neighborhood'] =='Fort Greene', 'Population'] = '26079'

# %%
DF.loc[DF['Neighborhood'] =='Fort Hamilton', 'Population'] = '9722'

# %%
DF.loc[DF['Neighborhood'] =='Fresh Meadows', 'Population'] = '17812'

# %%
DF.loc[DF['Neighborhood'] =='Gerritsen Beach', 'Population'] = '64518'

# %%
DF.loc[DF['Neighborhood'] =='Glen Oaks', 'Population'] = '22571'

# %%
DF.loc[DF['Neighborhood'] =='Glendale', 'Population'] = '32496'

# %%
DF.loc[DF['Neighborhood'] =='Gowanus', 'Population'] = '67649'

# %%
DF.loc[DF['Neighborhood'] =='Gramercy Park', 'Population'] = '27988'

# %%
DF.loc[DF['Neighborhood'] =='Gravesend', 'Population'] = '29436'

# %%
DF.loc[DF['Neighborhood'] =='Green Point', 'Population'] = '34719'

# %%
DF.loc[DF['Neighborhood'] =='Greenwich Village', 'Population'] = '28559'

# %%
DF.loc[DF['Neighborhood'] =='Greenwood', 'Population'] = '35733'

# %%
DF.loc[DF['Neighborhood'] =='Harding Park', 'Population'] = '53686'

# %%
DF.loc[DF['Neighborhood'] =='Harlem', 'Population'] = '133184'

# %%
DF.loc[DF['Neighborhood'] =='High Bridge', 'Population'] = '36663'

# %%
DF.loc[DF['Neighborhood'] =='Homecrest', 'Population'] = '44316'

# %%
DF.loc[DF['Neighborhood'] =='Howard Beach', 'Population'] = '26148'

# %%
DF.loc[DF['Neighborhood'] =='Hunters Point', 'Population'] = '63271'

# %%
DF.loc[DF['Neighborhood'] =='Hunts Point', 'Population'] = '27204'

# %%
DF.loc[DF['Neighborhood'] =='Jackson Heights', 'Population'] = '108152'

# %%
DF.loc[DF['Neighborhood'] =='Jamaica', 'Population'] = '217706'

# %%
DF.loc[DF['Neighborhood'] =='Kew Gardens', 'Population'] = '23278'

# %%
DF.loc[DF['Neighborhood'] =='Little Neck', 'Population'] = '24739'

# %%
DF.loc[DF['Neighborhood'] =='Locust Point', 'Population'] = '1625'

# %%
DF.loc[DF['Neighborhood'] =='Long Island City', 'Population'] = '60642'

# %%
DF.loc[DF['Neighborhood'] =='Lower East Side', 'Population'] = '72957'

# %%
DF.loc[DF['Neighborhood'] =='Malba', 'Population'] = '1108'

# %%
DF.loc[DF['Neighborhood'] =='Manhattan Beach', 'Population'] = '7160'

# %%
DF.loc[DF['Neighborhood'] =='Marine Park', 'Population'] = '45231'

# %%
DF.loc[DF['Neighborhood'] =='Maspeth', 'Population'] = '30516'

# %%
DF.loc[DF['Neighborhood'] =='Mid Island', 'Population'] = '73637'

# %%
DF.loc[DF['Neighborhood'] =='Middle Village', 'Population'] = '37929'

# %%
DF.loc[DF['Neighborhood'] =='Midwood', 'Population'] = '52835'

# %%
DF.loc[DF['Neighborhood'] =='Morningside Heights', 'Population'] = '55929'

# %%
DF.loc[DF['Neighborhood'] =='Morris Park', 'Population'] = '29250'

# %%
DF.loc[DF['Neighborhood'] =='New Hyde Park', 'Population'] = '22571'

# %%
#Remove New Utrecht , swap for Bensonhurst

DF.loc[DF['Neighborhood'] =='New Utrecht', 'Population'] = ''

# %%
DF.loc[DF['Neighborhood'] =='NoHo', 'Population'] = '4768'

# %%
DF.loc[DF['Neighborhood'] =='Ocean Hill', 'Population'] = '31935'

# %%
DF.loc[DF['Neighborhood'] =='Ozone Park', 'Population'] = '97254'

# %%
DF.loc[DF['Neighborhood'] =='Park Slope', 'Population'] = '67649'

# %%
DF.loc[DF['Neighborhood'] =='Parkchester', 'Population'] = '29821'

# %%
DF.loc[DF['Neighborhood'] =='Pelham Bay', 'Population'] = '26583'

# %%
DF.loc[DF['Neighborhood'] =='Pelham Gardens', 'Population'] = '28903'

# %%
DF.loc[DF['Neighborhood'] =='Pelham Parkway', 'Population'] = '30073'

# %%
DF.loc[DF['Neighborhood'] =='Port Richmond', 'Population'] = '20191'

# %%
DF.loc[DF['Neighborhood'] =='Prospect Park', 'Population'] = '19095'

# %%
DF.loc[DF['Neighborhood'] =='Queens Village', 'Population'] = '52504'

# %%
DF.loc[DF['Neighborhood'] =='Red Hook', 'Population'] = '38353'

# %%
DF.loc[DF['Neighborhood'] =='Rego Park', 'Population'] = '28260'

# %%
DF.loc[DF['Neighborhood'] =='Richmond Hill', 'Population'] = '62982'

# %%
DF.loc[DF['Neighborhood'] =='Ridgewood', 'Population'] = '69317'

# %%
DF.loc[DF['Neighborhood'] =='Riverdale', 'Population'] = '27860'

# %%
DF.loc[DF['Neighborhood'] =='Rockaway', 'Population'] = '50058'

# %%
DF.loc[DF['Neighborhood'] =='Rosedale', 'Population'] = '25063'

# %%
DF.loc[DF['Neighborhood'] =='Schuylerville', 'Population'] = '44167'

# %%
DF.loc[DF['Neighborhood'] =='Seagate', 'Population'] = '31965'

# %%
DF.loc[DF['Neighborhood'] =='Sheepshead Bay', 'Population'] = '64518'

# %%
DF.loc[DF['Neighborhood'] =='Soho', 'Population'] = '42742'

# %%
DF.loc[DF['Neighborhood'] =='Soundview', 'Population'] = '78667'

# %%
DF.loc[DF['Neighborhood'] =='South Shore', 'Population'] = '14'

# %%
# Too specific will remove later
DF.loc[DF['Neighborhood'] =='South Street Seaport', 'Population'] = ''

# %%
# Too specific will remove later
DF.loc[DF['Neighborhood'] =='Springfield', 'Population'] = ''

# %%
DF.loc[DF['Neighborhood'] =='Springfield Gardens', 'Population'] = '45541'

# %%
DF.loc[DF['Neighborhood'] =='Stapleton', 'Population'] = '26453'

# %%
DF.loc[DF['Neighborhood'] =='Stuyvesant Heights', 'Population'] = '63504'

# %%
DF.loc[DF['Neighborhood'] =='Sunnyside', 'Population'] = '63271'

# %%
DF.loc[DF['Neighborhood'] =='Sunset Park', 'Population'] = '126381'

# %%
DF.loc[DF['Neighborhood'] =='Throggs Neck', 'Population'] = '21009'

# %%
DF.loc[DF['Neighborhood'] =='Tremont', 'Population'] = '42423'

# %%
DF.loc[DF['Neighborhood'] =='Tribeca', 'Population'] = '42742'

# %%
DF.loc[DF['Neighborhood'] =='Two Bridges', 'Population'] = '12208'

# %%
DF.loc[DF['Neighborhood'] =='Upper East Side', 'Population'] = '61207'

# %%
DF.loc[DF['Neighborhood'] =='Upper West Side', 'Population'] = '132378'

# %%
DF.loc[DF['Neighborhood'] =='Van Nest', 'Population'] = '29250'

# %%
DF.loc[DF['Neighborhood'] =='Vinegar Hill', 'Population'] = '34495'

# %%
DF.loc[DF['Neighborhood'] =='Wakefield', 'Population'] = '42483'

# %%
DF.loc[DF['Neighborhood'] =='Washington Heights', 'Population'] = '151574'

# %%
DF.loc[DF['Neighborhood'] =='West Farms', 'Population'] = '35011'

# %%
DF.loc[DF['Neighborhood'] =='Westchester Square', 'Population'] = '29250'

# %%
DF.loc[DF['Neighborhood'] =='Whitestone', 'Population'] = '30773'

# %%
DF.loc[DF['Neighborhood'] =='Williamsbridge', 'Population'] = '61321'

# %%
DF.loc[DF['Neighborhood'] =='Williamsburg', 'Population'] = '67084'

# %%
DF.loc[DF['Neighborhood'] =='Windsor Terrace', 'Population'] = '20988'

# %%
DF.loc[DF['Neighborhood'] =='Woodhaven', 'Population'] = '56674'

# %%
DF.loc[DF['Neighborhood'] =='Woodlawn', 'Population'] = '42483'

# %%
DF.loc[DF['Neighborhood'] =='Woodside', 'Population'] = '45099'

# %%
DF.head(10)
# Out:
#                                              Address     Neighborhood  \
# 0             2 E 55th St Unit 803New York, NY 10022    Gramercy Park
# 1  Central Park Tower Penthouse-217 W 57th New Yo...          Chelsea
# 2            620 Sinclair AveStaten Island, NY 10312      South Shore
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022    Gramercy Park
# 4                      5 E 64th StNew York, NY 10065  Upper East Side
# 5                      584 Park PlBrooklyn, NY 11238    Crown Heights
# 6           157 W 126th St Unit 1BNew York, NY 10027           Harlem
# 7             177 Benedict RdStaten Island, NY 10304        Stapleton
# 8             875 Morrison Ave Apt 3MBronx, NY 10473        Soundview
# 9           1350 Ocean Pkwy Apt 5GBrooklyn, NY 11230     Borough Park
#
#   Population  Square Miles  Population Density
# 0      27988           NaN                 NaN
# 1      70150           NaN                 NaN
# 2         14           NaN                 NaN
# ...

# %%
DF.tail(10)
# Out:
#                                                 Address     Neighborhood  \
# 4544             342 E 53rd St Apt 6CNew York, NY 10022    Gramercy Park
# 4545                      448 40th StBrooklyn, NY 11232      Sunset Park
# 4546            700 Park Ave Unit 20ANew York, NY 10021  Upper East Side
# 4547  2351 Adam Clayton Powell Jr Blvd Apt 614Manhat...           Harlem
# 4548              2825-2827 W 15th StBrooklyn, NY 11224     Coney Island
# 4549            222 E 80th St Apt 3AManhattan, NY 10075  Upper East Side
# 4550             97-40 62 Dr Unit LgRego Park, NY 11374        Rego Park
# 4551        427 W 21st St Unit GardenNew York, NY 10011          Chelsea
# 4552         91-23 Corona Ave Unit 4GElmhurst, NY 11373         Elmhurst
# 4553          460 Neptune Ave Apt 14OBrooklyn, NY 11224   Brighton Beach
#
#      Population  Square Miles  Population Density
# 4544      27988           NaN                 NaN
# 4545     126381           NaN                 NaN
# ...

# %%
#Neighborhoods have now been expanded to be more specific
#Populations have been updated to reflect these neighborhoods

#Will come back to make minor revisions

# %% [markdown]
# ## Input Square Miles based on Neighborhood

# %%
DF.loc[DF['Neighborhood'] =='Allerton', 'Square Miles'] = '.79'

# %%
DF.loc[DF['Neighborhood'] =='Astoria', 'Square Miles'] = '2.14'

# %%
DF.loc[DF['Neighborhood'] =='Bath Beach', 'Square Miles'] = '1.03'

# %%
DF.loc[DF['Neighborhood'] =='Battery Park City', 'Square Miles'] = '.14'

# %%
DF.loc[DF['Neighborhood'] =='Bay Chester', 'Square Miles'] = '1.42'

# %%
DF.loc[DF['Neighborhood'] =='Bay Ridge', 'Square Miles'] = '1.71'

# %%
DF.loc[DF['Neighborhood'] =='Baychester', 'Square Miles'] = '1.42'

# %%
DF.loc[DF['Neighborhood'] =='Bayside', 'Square Miles'] = '6.68'

# %%
DF.loc[DF['Neighborhood'] =='Bedford-Stuyvesant', 'Square Miles'] = '2.97'

# %%
DF.loc[DF['Neighborhood'] =='Beechhurst', 'Square Miles'] = '1.2'

# %%
DF.loc[DF['Neighborhood'] =='Bellerose', 'Square Miles'] = '.92'

# %%
DF.loc[DF['Neighborhood'] =='Belmont', 'Square Miles'] = '.64'

# %%
DF.loc[DF['Neighborhood'] =='Bensonhurst', 'Square Miles'] = '2.62'

# %%
DF.loc[DF['Neighborhood'] =='Boerum Hill', 'Square Miles'] = '.46'

# %%
DF.loc[DF['Neighborhood'] =='Borough Park', 'Square Miles'] = '2.25'

# %%
DF.loc[DF['Neighborhood'] =='Brooklyn Heights', 'Square Miles'] = '.34'

# %%
DF.loc[DF['Neighborhood'] =='Brownsville', 'Square Miles'] = '1.16'

# %%
DF.loc[DF['Neighborhood'] =='Cambria Heights', 'Square Miles'] = '1.08'

# %%
DF.loc[DF['Neighborhood'] =='Canarsie', 'Square Miles'] = '3.13'

# %%
DF.loc[DF['Neighborhood'] =='Carroll Gardens', 'Square Miles'] = '0.78'

# %%
DF.loc[DF['Neighborhood'] =='Castle Hill', 'Square Miles'] = '1.04'

# %%
DF.loc[DF['Neighborhood'] =='Chelsea', 'Square Miles'] = '.77'

# %%
DF.loc[DF['Neighborhood'] =='City Island', 'Square Miles'] = '.44'

# %%
DF.loc[DF['Neighborhood'] =='Clason Point', 'Square Miles'] = '1.4'

# %%
DF.loc[DF['Neighborhood'] =='Co-op City', 'Square Miles'] = '1.39'

# %%
DF.loc[DF['Neighborhood'] =='College Point', 'Square Miles'] = '1.4'

# %%
DF.loc[DF['Neighborhood'] =='Coney Island', 'Square Miles'] = '1.14'

# %%
DF.loc[DF['Neighborhood'] =='Corona', 'Square Miles'] = '2.25'

# %%
DF.loc[DF['Neighborhood'] =='Country Club', 'Square Miles'] = '.82'

# %%
DF.loc[DF['Neighborhood'] =='Crotona Park East', 'Square Miles'] = '.35'

# %%
DF.loc[DF['Neighborhood'] =='Crown Heights', 'Square Miles'] = '2.78'

# %%
DF.loc[DF['Neighborhood'] =='Douglaston', 'Square Miles'] = '4.49'

# %%
DF.loc[DF['Neighborhood'] =='Dumbo', 'Square Miles'] = '.06'

# %%
DF.loc[DF['Neighborhood'] =='Dyker Heights', 'Square Miles'] = '1.43'

# %%
DF.loc[DF['Neighborhood'] =='East Harlem', 'Square Miles'] = '1.54'

# %%
DF.loc[DF['Neighborhood'] =='East New York', 'Square Miles'] = '3.96'

# %%
DF.loc[DF['Neighborhood'] =='East Village', 'Square Miles'] = '.94'

# %%
DF.loc[DF['Neighborhood'] =='Edenwald', 'Square Miles'] = '1.5'

# %%
DF.loc[DF['Neighborhood'] =='Elmhurst', 'Square Miles'] = '1.25'

# %%
DF.loc[DF['Neighborhood'] =='Financial District', 'Square Miles'] = '.33'

# %%
DF.loc[DF['Neighborhood'] =='Flatbush', 'Square Miles'] = '2.4'

# %%
DF.loc[DF['Neighborhood'] =='Floral Park', 'Square Miles'] = '.56'

# %%
DF.loc[DF['Neighborhood'] =='Flushing', 'Square Miles'] = '2.03'

# %%
DF.loc[DF['Neighborhood'] =='Fordham', 'Square Miles'] = '.64'

# %%
DF.loc[DF['Neighborhood'] =='Fordham Heights', 'Square Miles'] = '.19'

# %%
DF.loc[DF['Neighborhood'] =='Forest Hills', 'Square Miles'] = '2.6'

# %%
DF.loc[DF['Neighborhood'] =='Fort Greene', 'Square Miles'] = '.98'

# %%
DF.loc[DF['Neighborhood'] =='Fort Hamilton', 'Square Miles'] = '1.62'

# %%
DF.loc[DF['Neighborhood'] =='Fresh Meadows', 'Square Miles'] = '2.28'

# %%
DF.loc[DF['Neighborhood'] =='Gerritsen Beach', 'Square Miles'] = '.98'

# %%
DF.loc[DF['Neighborhood'] =='Glen Oaks', 'Square Miles'] = '1.31'

# %%
DF.loc[DF['Neighborhood'] =='Glendale', 'Square Miles'] = '2.72'

# %%
DF.loc[DF['Neighborhood'] =='Gowanus', 'Square Miles'] = '.42'

# %%
DF.loc[DF['Neighborhood'] =='Gramercy Park', 'Square Miles'] = '.17'

# %%
DF.loc[DF['Neighborhood'] =='Gravesend', 'Square Miles'] = '1.46'

# %%
DF.loc[DF['Neighborhood'] =='Greenpoint', 'Square Miles'] = '2.91'

# %%
DF.loc[DF['Neighborhood'] =='Greenwich Village', 'Square Miles'] = '.73'

# %%
DF.loc[DF['Neighborhood'] =='Greenwood', 'Square Miles'] = '.93'

# %%
DF.loc[DF['Neighborhood'] =='Harding Park', 'Square Miles'] = '.26'

# %%
DF.loc[DF['Neighborhood'] =='Harlem', 'Square Miles'] = '1.96'

# %%
DF.loc[DF['Neighborhood'] =='High Bridge', 'Square Miles'] = '.52'

# %%
DF.loc[DF['Neighborhood'] =='Homecrest', 'Square Miles'] = '1.12'

# %%
DF.loc[DF['Neighborhood'] =='Howard Beach', 'Square Miles'] = '2.66'

# %%
DF.loc[DF['Neighborhood'] =='Hunters Point', 'Square Miles'] = '.62'

# %%
DF.loc[DF['Neighborhood'] =='Hunts Point', 'Square Miles'] = '.94'

# %%
DF.loc[DF['Neighborhood'] =='Jackson Heights', 'Square Miles'] = '.77'

# %%
DF.loc[DF['Neighborhood'] =='Jamaica', 'Square Miles'] = '2.66'

# %%
DF.loc[DF['Neighborhood'] =='Kew Gardens', 'Square Miles'] = '1.03'

# %%
DF.loc[DF['Neighborhood'] =='Little Neck', 'Square Miles'] = '4.41'

# %%
DF.loc[DF['Neighborhood'] =='Locust Point', 'Square Miles'] = '.5'

# %%
DF.loc[DF['Neighborhood'] =='Long Island City', 'Square Miles'] = '1.54'

# %%
DF.loc[DF['Neighborhood'] =='Lower East Side', 'Square Miles'] = '.78'

# %%
DF.loc[DF['Neighborhood'] =='Malba', 'Square Miles'] = '.55'

# %%
DF.loc[DF['Neighborhood'] =='Manhattan Beach', 'Square Miles'] = '.31'

# %%
DF.loc[DF['Neighborhood'] =='Marine Park', 'Square Miles'] = '2.78'

# %%
DF.loc[DF['Neighborhood'] =='Maspeth', 'Square Miles'] = '2.94'

# %%
DF.loc[DF['Neighborhood'] =='Mid Island', 'Square Miles'] = '.42'

# %%
DF.loc[DF['Neighborhood'] =='Middle Village', 'Square Miles'] = '1.93'

# %%
DF.loc[DF['Neighborhood'] =='Midwood', 'Square Miles'] = '2.02'

# %%
DF.loc[DF['Neighborhood'] =='Morningside Heights', 'Square Miles'] = '.46'

# %%
DF.loc[DF['Neighborhood'] =='Morris Heights', 'Square Miles'] = '.37'

# %%
DF.loc[DF['Neighborhood'] =='Morris Park', 'Square Miles'] = '1.3'

# %%
DF.loc[DF['Neighborhood'] =='New Hyde Park', 'Square Miles'] = '.52'

# %%
DF.loc[DF['Neighborhood'] =='New Utrecht', 'Square Miles'] = '.85'

# %%
DF.loc[DF['Neighborhood'] =='Noho', 'Square Miles'] = '.16'

# %%
DF.loc[DF['Neighborhood'] =='Ocean Hill', 'Square Miles'] = '.45'

# %%
DF.loc[DF['Neighborhood'] =='Ozone Park', 'Square Miles'] = '3.4'

# %%
DF.loc[DF['Neighborhood'] =='Park Slope', 'Square Miles'] = '.66'

# %%
DF.loc[DF['Neighborhood'] =='Parkchester', 'Square Miles'] = '.75'

# %%
DF.loc[DF['Neighborhood'] =='Pelham Bay', 'Square Miles'] = '.71'

# %%
DF.loc[DF['Neighborhood'] =='Pelham Gardens', 'Square Miles'] = '.77'

# %%
DF.loc[DF['Neighborhood'] =='Pelham Parkway', 'Square Miles'] = '.85'

# %%
DF.loc[DF['Neighborhood'] =='Port Richmond', 'Square Miles'] = '.99'

# %%
DF.loc[DF['Neighborhood'] =='Prospect Heights', 'Square Miles'] = '.47'

# %%
DF.loc[DF['Neighborhood'] =='Prospect Park', 'Square Miles'] = '1.39'

# %%
DF.loc[DF['Neighborhood'] =='Queens Village', 'Square Miles'] = '1.86'

# %%
DF.loc[DF['Neighborhood'] =='Red Hook', 'Square Miles'] = '.84'

# %%
DF.loc[DF['Neighborhood'] =='Rego Park', 'Square Miles'] = '1.61'

# %%
DF.loc[DF['Neighborhood'] =='Richmond Hill', 'Square Miles'] = '1.14'

# %%
DF.loc[DF['Neighborhood'] =='Ridgewood', 'Square Miles'] = '2.45'

# %%
DF.loc[DF['Neighborhood'] =='Riverdale', 'Square Miles'] = '3.52'

# %%
DF.loc[DF['Neighborhood'] =='Rockaway', 'Square Miles'] = '11.5'

# %%
DF.loc[DF['Neighborhood'] =='Rosedale', 'Square Miles'] = '1.78'

# %%
DF.loc[DF['Neighborhood'] =='Schuylerville', 'Square Miles'] = '.58'

# %%
DF.loc[DF['Neighborhood'] =='Seagate', 'Square Miles'] = '.27'

# %%
DF.loc[DF['Neighborhood'] =='Sheepshead Bay', 'Square Miles'] = '1.98'

# %%
DF.loc[DF['Neighborhood'] =='Soho', 'Square Miles'] = '.26'

# %%
DF.loc[DF['Neighborhood'] =='Soundview', 'Square Miles'] = '.92'

# %%
DF.loc[DF['Neighborhood'] =='South Shore', 'Square Miles'] = '.58'

# %%
DF.loc[DF['Neighborhood'] =='South Street Seaport', 'Square Miles'] = '.1'

# %%
DF.loc[DF['Neighborhood'] =='Springfield', 'Square Miles'] = '.25'

# %%
DF.loc[DF['Neighborhood'] =='Springfield Gardens', 'Square Miles'] = '3,3'

# %%
DF.loc[DF['Neighborhood'] =='Stapleton', 'Square Miles'] = '.53'

# %%
DF.loc[DF['Neighborhood'] =='Stuyvesant Heights', 'Square Miles'] = '.42'

# %%
DF.loc[DF['Neighborhood'] =='Sunnyside', 'Square Miles'] = '.8'

# %%
DF.loc[DF['Neighborhood'] =='Sunset Park', 'Square Miles'] = '2.57'

# %%
DF.loc[DF['Neighborhood'] =='Throggs Neck', 'Square Miles'] = '.92'

# %%
DF.loc[DF['Neighborhood'] =='Tremont', 'Square Miles'] = '.68'

# %%
DF.loc[DF['Neighborhood'] =='Tribeca', 'Square Miles'] = '.48'

# %%
DF.loc[DF['Neighborhood'] =='Two Bridges', 'Square Miles'] = '.26'

# %%
DF.loc[DF['Neighborhood'] =='Upper East Side', 'Square Miles'] = '1.76'

# %%
DF.loc[DF['Neighborhood'] =='Upper West Side', 'Square Miles'] = '1.9'

# %%
DF.loc[DF['Neighborhood'] =='Van Nest', 'Square Miles'] = '.5'

# %%
DF.loc[DF['Neighborhood'] =='Vinegar Hill', 'Square Miles'] = '.05'

# %%
DF.loc[DF['Neighborhood'] =='Wakefield', 'Square Miles'] = '1.46'

# %%
DF.loc[DF['Neighborhood'] =='Washington Heights', 'Square Miles'] = '1.64'

# %%
DF.loc[DF['Neighborhood'] =='West Farms', 'Square Miles'] = '.25'

# %%
DF.loc[DF['Neighborhood'] =='Westchester Square', 'Square Miles'] = '.62'

# %%
DF.loc[DF['Neighborhood'] =='Whitestone', 'Square Miles'] = '2.6'

# %%
DF.loc[DF['Neighborhood'] =='Williamsbridge', 'Square Miles'] = '.76'

# %%
DF.loc[DF['Neighborhood'] =='Williamsburg', 'Square Miles'] = '2.18'

# %%
DF.loc[DF['Neighborhood'] =='Windsor Terrace', 'Square Miles'] = '.5'

# %%
DF.loc[DF['Neighborhood'] =='Woodhaven', 'Square Miles'] = '1.9'

# %%
DF.loc[DF['Neighborhood'] =='Woodlawn', 'Square Miles'] = '.3'

# %%
DF.loc[DF['Neighborhood'] =='Woodside', 'Square Miles'] = '1.86'

# %%
#Checking to see if this is filled out.
#Some NaN for Square miles, lets look at what neighborhoods were missed

DF
# Out:
#                                                 Address     Neighborhood  \
# 0                2 E 55th St Unit 803New York, NY 10022    Gramercy Park
# 1     Central Park Tower Penthouse-217 W 57th New Yo...          Chelsea
# 2               620 Sinclair AveStaten Island, NY 10312      South Shore
# 3            2 E 55th St Unit 908W33Manhattan, NY 10022    Gramercy Park
# 4                         5 E 64th StNew York, NY 10065  Upper East Side
# ...                                                 ...              ...
# 4549            222 E 80th St Apt 3AManhattan, NY 10075  Upper East Side
# 4550             97-40 62 Dr Unit LgRego Park, NY 11374        Rego Park
# 4551        427 W 21st St Unit GardenNew York, NY 10011          Chelsea
# 4552         91-23 Corona Ave Unit 4GElmhurst, NY 11373         Elmhurst
# 4553          460 Neptune Ave Apt 14OBrooklyn, NY 11224   Brighton Beach
#
#      Population Square Miles  Population Density
# ...

# %%
# See all the rows

pd.set_option('display.max_rows', None)

# %%
#Identify which ones were null

DF[DF['Square Miles'].isnull()]
# Out:
#                                                Address    Neighborhood  \
# 54                473 Hicks St Apt 4Brooklyn, NY 11231    Cobble Hills
# 60          50 Brighton 1 Rd Unit 5HBrooklyn, NY 11235  Brighton Beach
# 76                234 Ocean View AveBrooklyn, NY 11235  Brighton Beach
# 252               122 Willoughby AveBrooklyn, NY 11205    Clinton Hill
# 279            11 Brighton 10th PathBrooklyn, NY 11235  Brighton Beach
# 313         445 Lafayette St Apt 14ANew York, NY 10003            NoHo
# 352              18-70 211 St Unit 2ABayside, NY 11360         bayside
# 393               238 Ocean View AveBrooklyn, NY 11235  Brighton Beach
# 394                       8 Lake AveBrooklyn, NY 11235  Brighton Beach
# 502              274 S 2nd St Apt 30Brooklyn, NY 11211     Green Point
# 503                     219 Frost StBrooklyn, NY 11211     Green Point
# 677                     65 Gates AveBrooklyn, NY 11238    Clinton Hill
# ...

# %%
DF.loc[DF['Neighborhood'] =='Brighton Beach', 'Square Miles'] = '.73'

# %%
DF.loc[DF['Neighborhood'] =='Cobble Hills', 'Square Miles'] = '.36'

# %%
DF.loc[DF['Neighborhood'] =='Clinton Hill', 'Square Miles'] = '.79'

# %%
DF.loc[DF['Neighborhood'] =='NoHo', 'Square Miles'] = '.16'

# %%
DF.loc[DF['Neighborhood'] =='bayside', 'Square Miles'] = '6.68'

# %%
DF.loc[DF['Neighborhood'] =='Green Point', 'Square Miles'] = '2.91'

# %%
DF.loc[DF['Neighborhood'] =='New Utretch', 'Square Miles'] = '.85'

# %%
DF.loc[DF['Neighborhood'] =='New Hyde park', 'Square Miles'] = '.52'

# %%
DF.loc[DF['Neighborhood'] =='Floral park', 'Square Miles'] = '.56'

# %%
DF.loc[DF['Neighborhood'] =='Gravesend', 'Square Miles'] = '1.46'

# %%
#Check
DF[DF['Square Miles'].isnull()]
# Out:
#                                        Address Neighborhood Population  \
# 1125           1998 Clinton AveBronx, NY 10457      Belmost        NaN
# 3523  2620 Ocean Pkwy Apt 6LBrooklyn, NY 11235   Gravesend         NaN
# 3555    1721 W 6th St Apt 4BBrooklyn, NY 11223   Gravesend         NaN
#
#      Square Miles  Population Density
# 1125          NaN                 NaN
# 3523          NaN                 NaN
# 3555          NaN                 NaN

# %%
# Checked which ones have null values.

# %%
# Will have to manually fix these 3 inputs.

# %%
DF.to_excel(r'/Users/winsontom/Desktop/Career Foundry/Part 8- Final CF Immersion/2.0 Project/Population_Density2.xlsx', index=False)

# %%
#Manual edits made on certain neighborhoods,population, and square miles with limited data.

# %%
DF_2 = pd.read_excel('/Users/winsontom/Desktop/Career Foundry/Part 8- Final CF Immersion/2.0 Project/Population_Density2.xlsx', sheet_name='Sheet1')

# %%
#Checking to see everything is filled out

DF_2.head(10)
# Out:
#                                              Address     Neighborhood  \
# 0             2 E 55th St Unit 803New York, NY 10022    Gramercy Park
# 1  Central Park Tower Penthouse-217 W 57th New Yo...          Chelsea
# 2            620 Sinclair AveStaten Island, NY 10312      South Shore
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022    Gramercy Park
# 4                      5 E 64th StNew York, NY 10065  Upper East Side
# 5                      584 Park PlBrooklyn, NY 11238    Crown Heights
# 6           157 W 126th St Unit 1BNew York, NY 10027           Harlem
# 7             177 Benedict RdStaten Island, NY 10304        Stapleton
# 8             875 Morrison Ave Apt 3MBronx, NY 10473        Soundview
# 9           1350 Ocean Pkwy Apt 5GBrooklyn, NY 11230     Borough Park
#
#    Population Square Miles  Population Density
# 0       27988          .17                 NaN
# 1       70150          .77                 NaN
# 2      168027          .58                 NaN
# ...

# %%
DF_2.tail(10)
# Out:
#                                                 Address     Neighborhood  \
# 4544             342 E 53rd St Apt 6CNew York, NY 10022    Gramercy Park
# 4545                      448 40th StBrooklyn, NY 11232      Sunset Park
# 4546            700 Park Ave Unit 20ANew York, NY 10021  Upper East Side
# 4547  2351 Adam Clayton Powell Jr Blvd Apt 614Manhat...           Harlem
# 4548              2825-2827 W 15th StBrooklyn, NY 11224     Coney Island
# 4549            222 E 80th St Apt 3AManhattan, NY 10075  Upper East Side
# 4550             97-40 62 Dr Unit LgRego Park, NY 11374        Rego Park
# 4551        427 W 21st St Unit GardenNew York, NY 10011          Chelsea
# 4552         91-23 Corona Ave Unit 4GElmhurst, NY 11373         Elmhurst
# 4553          460 Neptune Ave Apt 14OBrooklyn, NY 11224   Brighton Beach
#
#       Population Square Miles  Population Density
# 4544       27988          .17                 NaN
# 4545      126381         2.57                 NaN
# ...

# %%
#Drop the column to recreate column with formula

DF_2.drop(columns=['Population Density'], inplace=True)

# %%
DF_2.head(1)
# Out:
#                                   Address   Neighborhood  Population  \
# 0  2 E 55th St Unit 803New York, NY 10022  Gramercy Park       27988
#
#   Square Miles
# 0          .17

# %%
DF_2['Population_Density'] = DF2['Population'] / DF2['Square Miles']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %%
#Error is due to different data types

# %%
#Exploring data types

# %%
#Need to change Square Miles column from object to number
DF_2.dtypes
# Out:
# Address         object
# Neighborhood    object
# Population       int64
# Square Miles    object
# dtype: object

# %%
DF_2['Square Miles'] = pd.to_numeric(DF_2['Square Miles'], errors='coerce')

# %%
DF_2['Population'] = pd.to_numeric(DF_2['Population'], errors='coerce')

# %%
#Data types are fixed, we should be able to divide columns now

DF_2.dtypes
# Out:
# Address          object
# Neighborhood     object
# Population        int64
# Square Miles    float64
# dtype: object

# %%
#Trying formula to create Population Density Column again

DF_2['Population_Density'] = DF_2['Population'] / DF_2['Square Miles']

# %%
#Sucessfully created an objective way to measure how dense a neighborhood is

DF_2.head(10)
# Out:
#                                              Address     Neighborhood  \
# 0             2 E 55th St Unit 803New York, NY 10022    Gramercy Park
# 1  Central Park Tower Penthouse-217 W 57th New Yo...          Chelsea
# 2            620 Sinclair AveStaten Island, NY 10312      South Shore
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022    Gramercy Park
# 4                      5 E 64th StNew York, NY 10065  Upper East Side
# 5                      584 Park PlBrooklyn, NY 11238    Crown Heights
# 6           157 W 126th St Unit 1BNew York, NY 10027           Harlem
# 7             177 Benedict RdStaten Island, NY 10304        Stapleton
# 8             875 Morrison Ave Apt 3MBronx, NY 10473        Soundview
# 9           1350 Ocean Pkwy Apt 5GBrooklyn, NY 11230     Borough Park
#
#    Population  Square Miles  Population_Density
# 0       27988          0.17       164635.294118
# 1       70150          0.77        91103.896104
# 2      168027          0.58       289701.724138
# ...

# %%
DF_Density = DF_2.sort_values(by='Population_Density')

# %%
DF_Density.reset_index(drop=True, inplace=True)

# %%
#DF_Density shows all listings from the least dense neighborhood to the most dense
#This is perfect for people specifically looking for less packed areas, wants more living space.

DF_Density
# Out:
#                                                 Address          Neighborhood  \
# 0                           34 Center DrMalba, NY 11357                 Malba
# 1                        14458 BoulevardMalba, NY 11357                 Malba
# 2                        14446 BoulevardMalba, NY 11357                 Malba
# 3                   4384 Locust Point DrBronx, NY 10465          Locust Point
# 4               22-63 Nameoke AveFar Rockaway, NY 11691              Rockaway
# 5     12310 Ocean Promenade Apt 7HRockaway Park, NY ...              Rockaway
# 6      144 Beach 121st St Apt 1ARockaway Park, NY 11694              Rockaway
# 7                133 Beach 116th St # FQueens, NY 11694              Rockaway
# 8             190 Beach 109th StRockaway Park, NY 11694              Rockaway
# 9      13811 Beach Channel Dr Unit 8CBrooklyn, NY 11694              Rockaway
# 10         1040 Neilson St Apt 2HFar Rockaway, NY 11691              Rockaway
# ...

# %%
DF_2.to_excel(r'/Users/winsontom/Desktop/Career Foundry/Part 8- Final CF Immersion/2.0 Project/Population_Density_Completed.xlsx', index=False)

# %%
DF_Density.to_excel(r'/Users/winsontom/Desktop/Career Foundry/Part 8- Final CF Immersion/2.0 Project/Population_Density_Least_To_Greatest.xlsx', index=False)
